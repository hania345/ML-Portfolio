# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'C:\\Users\\aksha_t30bq4h\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
import numpy as num
num
# Out:
# <module 'numpy' from 'C:\\Users\\aksha_t30bq4h\\anaconda3\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
df=pd.read_csv("odi.csv")

# %%
df.shape
# Out:
# (26, 7)

# %%
df.isnull().sum()
# Out:
# Team 1    0
# Team 2    0
# Format    0
# Date      0
# Venue     0
# Result    0
# Status    0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                         Team 1                      Team 2 Format  \
# 0     New Zealand299 (49.3 ov)       Pakistan252 (46.1 ov)    ODI
# 1      Pakistan334/6 (50.0 ov)    New Zealand232 (43.4 ov)    ODI
# 2      Pakistan287/6 (50.0 ov)    New Zealand261 (49.1 ov)    ODI
# 3      Pakistan280/9 (50.0 ov)  New Zealand281/8 (48.1 ov)    ODI
# 4     New Zealand261 (49.5 ov)       Pakistan182 (43.0 ov)    ODI
# 5   New Zealand255/9 (50.0 ov)     Pakistan258/4 (48.1 ov)    ODI
# 6     Sri Lanka297/9 (50.0 ov)     Pakistan299/5 (48.2 ov)    ODI
# 7      Pakistan305/7 (50.0 ov)      Sri Lanka238 (46.5 ov)    ODI
# 8                     Pakistan                   Sri Lanka    ODI
# 9      Bangladesh197 (38.5 ov)     Pakistan194/3 (39.3 ov)    ODI
# 10    Sri Lanka291/8 (50.0 ov)    Afghanistan289 (37.4 ov)    ODI
# 11   Bangladesh334/5 (50.0 ov)    Afghanistan245 (44.3 ov)    ODI
# 12      Australia210 (41.5 ov)     Pakistan210/1 (37.4 ov)    ODI
# ...

# %%
df['Venue'].value_counts()
# Out:
# Venue
# Karachi       9
# Lahore        9
# Rawalpindi    8
# Name: count, dtype: int64

# %%
df = pd.DataFrame(df)

# Example: Mark as canceled if the venue is 'Stadium A'
df['canceled'] = df['Result'].apply(lambda x: 'Yes' if x == 'CANCELED' else 'No')

# %%
df
# Out:
#                         Team 1                      Team 2 Format  \
# 0     New Zealand299 (49.3 ov)       Pakistan252 (46.1 ov)    ODI
# 1      Pakistan334/6 (50.0 ov)    New Zealand232 (43.4 ov)    ODI
# 2      Pakistan287/6 (50.0 ov)    New Zealand261 (49.1 ov)    ODI
# 3      Pakistan280/9 (50.0 ov)  New Zealand281/8 (48.1 ov)    ODI
# 4     New Zealand261 (49.5 ov)       Pakistan182 (43.0 ov)    ODI
# 5   New Zealand255/9 (50.0 ov)     Pakistan258/4 (48.1 ov)    ODI
# 6     Sri Lanka297/9 (50.0 ov)     Pakistan299/5 (48.2 ov)    ODI
# 7      Pakistan305/7 (50.0 ov)      Sri Lanka238 (46.5 ov)    ODI
# 8                     Pakistan                   Sri Lanka    ODI
# 9      Bangladesh197 (38.5 ov)     Pakistan194/3 (39.3 ov)    ODI
# 10    Sri Lanka291/8 (50.0 ov)    Afghanistan289 (37.4 ov)    ODI
# 11   Bangladesh334/5 (50.0 ov)    Afghanistan245 (44.3 ov)    ODI
# 12      Australia210 (41.5 ov)     Pakistan210/1 (37.4 ov)    ODI
# ...

# %%
df['Team 1'].value_counts()
# Out:
# Team 1
# Pakistan                      4
# New Zealand299 (49.3 ov)      1
# Australia210 (41.5 ov)        1
# Zimbabwe206 (45.1 ov)         1
# Zimbabwe278/6 (50.0 ov)       1
# New Zealand288/7 (50.0 ov)    1
# New Zealand336/5 (50.0 ov)    1
# Pakistan375/3 (50.0 ov)       1
# Zimbabwe268/7 (50.0 ov)       1
# Pakistan296/9 (50.0 ov)       1
# Australia313/7 (50.0 ov)      1
# Australia348/8 (50.0 ov)      1
# Bangladesh334/5 (50.0 ov)     1
# Pakistan334/6 (50.0 ov)       1
# Sri Lanka291/8 (50.0 ov)      1
# Bangladesh197 (38.5 ov)       1
# Pakistan305/7 (50.0 ov)       1
# Sri Lanka297/9 (50.0 ov)      1
# New Zealand255/9 (50.0 ov)    1
# New Zealand261 (49.5 ov)      1
# Pakistan280/9 (50.0 ov)       1
# Pakistan287/6 (50.0 ov)       1
# Pakistan281/8 (50.0 ov)       1
# Name: count, dtype: int64

# %%
df['Team 2'].value_counts()
# Out:
# Team 2
# New Zealand                   3
# Pakistan252 (46.1 ov)         1
# New Zealand232 (43.4 ov)      1
# Pakistan208/4 (35.2 ov)       1
# Pakistan278/9 (50.0 ov)       1
# Pakistan291/5 (48.3 ov)       1
# Pakistan337/3 (48.2 ov)       1
# Zimbabwe334/5 (50.0 ov)       1
# Pakistan269/4 (47.2 ov)       1
# Zimbabwe68/0 (9.0 ov)         1
# Pakistan225 (45.2 ov)         1
# Pakistan352/4 (49.0 ov)       1
# Pakistan210/1 (37.4 ov)       1
# Afghanistan245 (44.3 ov)      1
# Afghanistan289 (37.4 ov)      1
# Pakistan194/3 (39.3 ov)       1
# Sri Lanka                     1
# Sri Lanka238 (46.5 ov)        1
# Pakistan299/5 (48.2 ov)       1
# Pakistan258/4 (48.1 ov)       1
# Pakistan182 (43.0 ov)         1
# New Zealand281/8 (48.1 ov)    1
# New Zealand261 (49.1 ov)      1
# Zimbabwe250/9 (48.5 ov)       1
# Name: count, dtype: int64

# %%
df['Team 1'].value_counts() + df['Team 2'].value_counts()
# Out:
# Afghanistan245 (44.3 ov)     NaN
# Afghanistan289 (37.4 ov)     NaN
# Australia210 (41.5 ov)       NaN
# Australia313/7 (50.0 ov)     NaN
# Australia348/8 (50.0 ov)     NaN
# Bangladesh197 (38.5 ov)      NaN
# Bangladesh334/5 (50.0 ov)    NaN
# New Zealand                  NaN
# New Zealand232 (43.4 ov)     NaN
# New Zealand255/9 (50.0 ov)   NaN
# New Zealand261 (49.1 ov)     NaN
# New Zealand261 (49.5 ov)     NaN
# New Zealand281/8 (48.1 ov)   NaN
# New Zealand288/7 (50.0 ov)   NaN
# New Zealand299 (49.3 ov)     NaN
# New Zealand336/5 (50.0 ov)   NaN
# Pakistan                     NaN
# Pakistan182 (43.0 ov)        NaN
# Pakistan194/3 (39.3 ov)      NaN
# Pakistan208/4 (35.2 ov)      NaN
# Pakistan210/1 (37.4 ov)      NaN
# Pakistan225 (45.2 ov)        NaN
# Pakistan252 (46.1 ov)        NaN
# Pakistan258/4 (48.1 ov)      NaN
# Pakistan269/4 (47.2 ov)      NaN
# Pakistan278/9 (50.0 ov)      NaN
# Pakistan280/9 (50.0 ov)      NaN
# Pakistan281/8 (50.0 ov)      NaN
# ...

# %%
df
# Out:
#                         Team 1                      Team 2 Format  \
# 0     New Zealand299 (49.3 ov)       Pakistan252 (46.1 ov)    ODI
# 1      Pakistan334/6 (50.0 ov)    New Zealand232 (43.4 ov)    ODI
# 2      Pakistan287/6 (50.0 ov)    New Zealand261 (49.1 ov)    ODI
# 3      Pakistan280/9 (50.0 ov)  New Zealand281/8 (48.1 ov)    ODI
# 4     New Zealand261 (49.5 ov)       Pakistan182 (43.0 ov)    ODI
# 5   New Zealand255/9 (50.0 ov)     Pakistan258/4 (48.1 ov)    ODI
# 6     Sri Lanka297/9 (50.0 ov)     Pakistan299/5 (48.2 ov)    ODI
# 7      Pakistan305/7 (50.0 ov)      Sri Lanka238 (46.5 ov)    ODI
# 8                     Pakistan                   Sri Lanka    ODI
# 9      Bangladesh197 (38.5 ov)     Pakistan194/3 (39.3 ov)    ODI
# 10    Sri Lanka291/8 (50.0 ov)    Afghanistan289 (37.4 ov)    ODI
# 11   Bangladesh334/5 (50.0 ov)    Afghanistan245 (44.3 ov)    ODI
# 12      Australia210 (41.5 ov)     Pakistan210/1 (37.4 ov)    ODI
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%b %d, %Y')

# Extract the year from the 'date' column into a new column 'year'
df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#                         Team 1                      Team 2 Format       Date  \
# 0     New Zealand299 (49.3 ov)       Pakistan252 (46.1 ov)    ODI 2023-05-07
# 1      Pakistan334/6 (50.0 ov)    New Zealand232 (43.4 ov)    ODI 2023-05-05
# 2      Pakistan287/6 (50.0 ov)    New Zealand261 (49.1 ov)    ODI 2023-05-03
# 3      Pakistan280/9 (50.0 ov)  New Zealand281/8 (48.1 ov)    ODI 2023-01-13
# 4     New Zealand261 (49.5 ov)       Pakistan182 (43.0 ov)    ODI 2023-01-11
# 5   New Zealand255/9 (50.0 ov)     Pakistan258/4 (48.1 ov)    ODI 2023-01-09
# 6     Sri Lanka297/9 (50.0 ov)     Pakistan299/5 (48.2 ov)    ODI 2019-10-02
# 7      Pakistan305/7 (50.0 ov)      Sri Lanka238 (46.5 ov)    ODI 2019-09-30
# 8                     Pakistan                   Sri Lanka    ODI 2019-09-27
# 9      Bangladesh197 (38.5 ov)     Pakistan194/3 (39.3 ov)    ODI 2023-09-06
# 10    Sri Lanka291/8 (50.0 ov)    Afghanistan289 (37.4 ov)    ODI 2023-09-05
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
rf
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
df.Year
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# 5     2023
# 6     2019
# 7     2019
# 8     2019
# 9     2023
# 10    2023
# 11    2023
# 12    2022
# 13    2022
# 14    2022
# 15    2015
# 16    2015
# 17    2015
# 18    2023
# 19    2023
# 20    2021
# 21    2021
# 22    2021
# 23    2020
# 24    2020
# 25    2020
# Name: Year, dtype: int32

# %%
train=df[df['Year']<'2020']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 train=df[df['Year']<'2020']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5803, in Series._cmp_method(self, other, op)
#    5800 lvalues = self._values
#    5801 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5803 res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
test=df[df["Year"]>'2023']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 test=df[df["Year"]>'2023']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5803, in Series._cmp_method(self, other, op)
#    5800 lvalues = self._values
#    5801 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5803 res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
test = df[df["Year"] > 2023]

# %%
train = df[df["Year"] < 2023]

# %%
train
# Out:
#                       Team 1                   Team 2 Format       Date  \
# 6   Sri Lanka297/9 (50.0 ov)  Pakistan299/5 (48.2 ov)    ODI 2019-10-02
# 7    Pakistan305/7 (50.0 ov)   Sri Lanka238 (46.5 ov)    ODI 2019-09-30
# 8                   Pakistan                Sri Lanka    ODI 2019-09-27
# 12    Australia210 (41.5 ov)  Pakistan210/1 (37.4 ov)    ODI 2022-04-02
# 13  Australia348/8 (50.0 ov)  Pakistan352/4 (49.0 ov)    ODI 2022-03-31
# 14  Australia313/7 (50.0 ov)    Pakistan225 (45.2 ov)    ODI 2022-03-29
# 15   Pakistan296/9 (50.0 ov)    Zimbabwe68/0 (9.0 ov)    ODI 2015-05-31
# 16   Zimbabwe268/7 (50.0 ov)  Pakistan269/4 (47.2 ov)    ODI 2015-05-29
# 17   Pakistan375/3 (50.0 ov)  Zimbabwe334/5 (50.0 ov)    ODI 2015-05-26
# 20                  Pakistan              New Zealand    ODI 2021-09-21
# 21                  Pakistan              New Zealand    ODI 2021-09-19
# 22                  Pakistan              New Zealand    ODI 2021-09-17
# ...

# %%
test
# Out:
# Empty DataFrame
# Columns: [Team 1, Team 2, Format, Date, Venue, Result, Status, canceled, Year]
# Index: []

# %%
predictors=["Year","Result","Team 1","Team 2"]

# %%
predictors
# Out:
# ['Year', 'Result', 'Team 1', 'Team 2']

# %%
rf.fit(train[predictors],train["canceled"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16220\2822980744.py in ?()
# ----> 1 rf.fit(train[predictors],train["canceled"])
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     341
#     342         # Validate or convert input data
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#     348         if sample_weight is not None:
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     580                 if "estimator" not in check_y_params:
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'Team1' and 'Team2' are the columns that contain categorical data
label_encoder = LabelEncoder()

# Apply LabelEncoder to columns with categorical data
train['Team 1'] = label_encoder.fit_transform(train['Team 1'])
train['Team 2'] = label_encoder.fit_transform(train['Team 2'])

# %%
train = pd.get_dummies(train, columns=['Team1', 'Team2'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 train = pd.get_dummies(train, columns=['Team1', 'Team2'], drop_first=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:164, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     162     raise TypeError("Input must be a list-like for parameter `columns`")
#     163 else:
# --> 164     data_to_encode = data[columns]
#     166 # validate prefixes and separator to avoid silently dropping cols
#     167 def check_len(item, name: str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
# ...

# %%
train
# Out:
#     Team 1  Team 2 Format       Date       Venue       Result     Status  \
# 13       2      13    ODI 2022-03-31      Lahore     Pakistan  Completed
# 1       13       2    ODI 2023-05-05     Karachi     Pakistan  Completed
# 23      17       9    ODI 2020-11-03  Rawalpindi     Zimbabwe  Completed
# 5        3       8    ODI 2023-01-09     Karachi     Pakistan  Completed
# 2       10       3    ODI 2023-05-03     Karachi     Pakistan  Completed
# 12       0       6    ODI 2022-04-02      Lahore     Pakistan  Completed
# 15      11      17    ODI 2015-05-31      Lahore           NR  Completed
# 3        8       4    ODI 2023-01-13     Karachi  New Zealand  Completed
# 4        4       5    ODI 2023-01-11     Karachi  New Zealand  Completed
# 21       7       1    ODI 2021-09-19  Rawalpindi     CANCELED  Completed
# 17      14      16    ODI 2015-05-26      Lahore     Pakistan  Completed
# 22       7       1    ODI 2021-09-17  Rawalpindi     CANCELED  Completed
# ...

# %%
RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
predi=rf.predict(test[predictors])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16220\1156390491.py in ?()
# ----> 1 predi=rf.predict(test[predictors])
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     816         -------
#     817         y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#     818             The predicted classes.
#     819         """
# --> 820         proba = self.predict_proba(X)
#     821
#     822         if self.n_outputs_ == 1:
#     823             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     858             classes corresponds to that in the attribute :term:`classes_`.
#     859         """
#     860         check_is_fitted(self)
#     861         # Check data
# --> 862         X = self._validate_X_predict(X)
# ...

# %%
# Check the shape of the test DataFrame
print(test.shape)

# If it's empty, inspect how the test DataFrame is created and whether it's being filtered properly
if test.shape[0] == 0:
    print("Test DataFrame is empty!")

# Check if predictors are correct and present in test
print(test[predictors].columns)
# Out:
# (6, 9)
# Index(['Year', 'Result', 'Team 1', 'Team 2'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Example of splitting data (make sure you have a valid predictors list)
train, test = train_test_split(df, test_size=0.2, random_state=42)

# %%
test
# Out:
#                        Team 1                    Team 2 Format       Date  \
# 8                    Pakistan                 Sri Lanka    ODI 2019-09-27
# 16    Zimbabwe268/7 (50.0 ov)   Pakistan269/4 (47.2 ov)    ODI 2015-05-29
# 0    New Zealand299 (49.3 ov)     Pakistan252 (46.1 ov)    ODI 2023-05-07
# 24      Zimbabwe206 (45.1 ov)   Pakistan208/4 (35.2 ov)    ODI 2020-11-01
# 11  Bangladesh334/5 (50.0 ov)  Afghanistan245 (44.3 ov)    ODI 2023-09-03
# 9     Bangladesh197 (38.5 ov)   Pakistan194/3 (39.3 ov)    ODI 2023-09-06
#
#          Venue       Result     Status canceled  Year
# 8      Karachi    ABANDONED  Completed       No  2019
# 16      Lahore     Pakistan  Completed       No  2015
# 0      Karachi  New Zealand  Completed       No  2023
# 24  Rawalpindi     Pakistan  Completed       No  2020
# 11      Lahore   Bangladesh  Completed       No  2023
# 9       Lahore     Pakistan  Completed       No  2023

# %%
df
# Out:
#                         Team 1                      Team 2 Format       Date  \
# 0     New Zealand299 (49.3 ov)       Pakistan252 (46.1 ov)    ODI 2023-05-07
# 1      Pakistan334/6 (50.0 ov)    New Zealand232 (43.4 ov)    ODI 2023-05-05
# 2      Pakistan287/6 (50.0 ov)    New Zealand261 (49.1 ov)    ODI 2023-05-03
# 3      Pakistan280/9 (50.0 ov)  New Zealand281/8 (48.1 ov)    ODI 2023-01-13
# 4     New Zealand261 (49.5 ov)       Pakistan182 (43.0 ov)    ODI 2023-01-11
# 5   New Zealand255/9 (50.0 ov)     Pakistan258/4 (48.1 ov)    ODI 2023-01-09
# 6     Sri Lanka297/9 (50.0 ov)     Pakistan299/5 (48.2 ov)    ODI 2019-10-02
# 7      Pakistan305/7 (50.0 ov)      Sri Lanka238 (46.5 ov)    ODI 2019-09-30
# 8                     Pakistan                   Sri Lanka    ODI 2019-09-27
# 9      Bangladesh197 (38.5 ov)     Pakistan194/3 (39.3 ov)    ODI 2023-09-06
# 10    Sri Lanka291/8 (50.0 ov)    Afghanistan289 (37.4 ov)    ODI 2023-09-05
# ...

# %%
predi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 predi
#
# NameError: name 'predi' is not defined

# %%
predictors
# Out:
# ['Year', 'Result', 'Team 1', 'Team 2']

# %%
rf
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
rf.predict
# Out:
# <bound method ForestClassifier.predict of RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)>

# %%
predi=rf.predict(test[predictors])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16220\1156390491.py in ?()
# ----> 1 predi=rf.predict(test[predictors])
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     816         -------
#     817         y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#     818             The predicted classes.
#     819         """
# --> 820         proba = self.predict_proba(X)
#     821
#     822         if self.n_outputs_ == 1:
#     823             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     858             classes corresponds to that in the attribute :term:`classes_`.
#     859         """
#     860         check_is_fitted(self)
#     861         # Check data
# --> 862         X = self._validate_X_predict(X)
# ...

# %%
from sklearn.model_selection import train_test_split

# Ensure the dataset is large enough for splitting
train, test = train_test_split(df, test_size=0.2, random_state=42)

# Check the size of train and test sets
print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
# Out:
# Train shape: (20, 9)
# Test shape: (6, 9)

# %%
from sklearn.metrics import accuracy_score

# %%
accr=accuracy_score(test["target"], predi)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 accr=accuracy_score(test["target"], predi)
#
# ...

# %%
accr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 accr
#
# NameError: name 'accr' is not defined

# %%
combined=pd.DataFrame(dict(actual=test["target"], prediction=preds))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 combined=pd.DataFrame(dict(actual=test["target"], prediction=preds))
#
# ...

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 pd.crosstab(index=combined["actual"], columns=combined["prediction"])
#
# NameError: name 'combined' is not defined

# %%
df["Venue"]=df["Venue"].astype("category").cat.codes

# %%
df["Team 1"]=df["Team 1"].astype("category").cat.codes

# %%
df["Team 2"]=df["Team 2"].astype("category").cat.codes

# %%
df
# Out:
#     Team 1  Team 2 Format       Date  Venue       Result     Status canceled  \
# 0        8      11    ODI 2023-05-07      0  New Zealand  Completed       No
# 1       16       3    ODI 2023-05-05      0     Pakistan  Completed       No
# 2       13       4    ODI 2023-05-03      0     Pakistan  Completed       No
# 3       11       5    ODI 2023-01-13      0  New Zealand  Completed       No
# 4        6       6    ODI 2023-01-11      0  New Zealand  Completed       No
# 5        5      12    ODI 2023-01-09      0     Pakistan  Completed       No
# 6       19      16    ODI 2019-10-02      0     Pakistan  Completed       No
# 7       15      20    ODI 2019-09-30      0     Pakistan  Completed       No
# 8       10      19    ODI 2019-09-27      0    ABANDONED  Completed       No
# 9        3       7    ODI 2023-09-06      1     Pakistan  Completed       No
# 10      18       1    ODI 2023-09-05      1    Sri Lanka  Completed       No
# ...

# %%
df["Result"]=(df["Result"]== "W")

# %%
df
# Out:
#     Team 1  Team 2 Format       Date  Venue  Result     Status canceled  Year
# 0        8      11    ODI 2023-05-07      0   False  Completed       No  2023
# 1       16       3    ODI 2023-05-05      0   False  Completed       No  2023
# 2       13       4    ODI 2023-05-03      0   False  Completed       No  2023
# 3       11       5    ODI 2023-01-13      0   False  Completed       No  2023
# 4        6       6    ODI 2023-01-11      0   False  Completed       No  2023
# 5        5      12    ODI 2023-01-09      0   False  Completed       No  2023
# 6       19      16    ODI 2019-10-02      0   False  Completed       No  2019
# 7       15      20    ODI 2019-09-30      0   False  Completed       No  2019
# 8       10      19    ODI 2019-09-27      0   False  Completed       No  2019
# 9        3       7    ODI 2023-09-06      1   False  Completed       No  2023
# 10      18       1    ODI 2023-09-05      1   False  Completed       No  2023
# ...
